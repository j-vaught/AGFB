# %% [markdown]
# # Rician Noise 1024 synthetic-image example
#
# Magnitude image noise from two independent Gaussian channels. This notebook starts from the same synthetic 1024 x 1024 image, applies one AGFB noise model, and displays the clean image, noisy image, and residual.

# %% [markdown]
# ## Setup
#
# Import the model function and notebook helpers. The autoreload lines help Jupyter pick up local source edits without restarting the kernel.

# %%
# Imports and local reloads.
# %load_ext autoreload
# %autoreload 2

import time

import torch

from agfb_noise import add_rician
from agfb_noise.notebook import show_noise_preview, summarize_tensors, synthetic_1024_image

# %% [markdown]
# ## Synthetic Image
#
# Create the shared 1024 x 1024 synthetic input on CUDA when available.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
seed = 123

clean = synthetic_1024_image(device=device)
clean.shape, clean.device, clean.dtype
# Out:
# (torch.Size([1, 1024, 1024]), device(type='cpu'), torch.float32)

# %% [markdown]
# ## Apply Noise
#
# Set the model parameters and corrupt the image.

# %%
def apply_model() -> torch.Tensor:
    return add_rician(clean, sigma=0.05, seed=seed, clamp=(0.0, 1.0))


noisy = apply_model()
delta = noisy - clean

# %% [markdown]
# ## Summary
#
# Report compact tensor statistics for the clean, noisy, and residual images.

# %%
summarize_tensors(
    {
        "clean": clean,
        "noisy": noisy,
        "delta": delta,
    }
)
# Out:
# [{'name': 'clean',
#   'min': 0.11334408074617386,
#   'q01': 0.1417168229818344,
#   'mean': 0.48850709199905396,
#   'q50': 0.5385441184043884,
#   'q99': 0.8480556011199951,
#   'max': 0.9545643329620361,
#   'std': 0.18355251848697662},
#  {'name': 'noisy',
#   'min': 0.002409044187515974,
#   'q01': 0.1122036874294281,
#   'mean': 0.4916806221008301,
#   'q50': 0.5338227152824402,
#   'q99': 0.8717243671417236,
#   'max': 1.0,
#   'std': 0.1885460466146469},
#  {'name': 'delta',
#   'min': -0.22788499295711517,
#   'q01': -0.11241402477025986,
#   'mean': 0.00317355222068727,
#   'q50': 0.003169506788253784,
#   'q99': 0.11901257932186127,
#   'max': 0.26611000299453735,
#   'std': 0.049802083522081375}]

# %% [markdown]
# ## Preview
#
# The preview down-samples the 1024 image for display. The residual uses a blue-white-garnet diverging map.

# %%
show_noise_preview(clean, noisy, title="Rician Noise")
# Out:
#     <section style="font-family:system-ui, sans-serif;">
#       <h2 style="font-size:18px; margin:0 0 10px 0; color:#000000;">Rician Noise</h2>
#       <div style="display:grid; grid-template-columns:repeat(3, minmax(0, 1fr)); gap:12px;">
#
#         <figure style="margin:0; min-width:0;">
#           <figcaption style="font:600 13px system-ui; color:#363636; margin-bottom:6px;">
#             Clean 1024 image
#           </figcaption>
#           <img
#             src="data:image/bmp;base64,..."
#             style="display:block; width:100%; image-rendering:auto; border:1px solid #000000;"
#           />
#         </figure>
#
#
#         <figure style="margin:0; min-width:0;">
#           <figcaption style="font:600 13px system-ui; color:#363636; margin-bottom:6px;">
#             Noisy image
#           </figcaption>
#           <img
#             src="data:image/bmp;base64,..."
#             style="display:block; width:100%; image-rendering:auto; border:1px solid #000000;"
#           />
#         </figure>
#
#
#         <figure style="margin:0; min-width:0;">
#           <figcaption style="font:600 13px system-ui; color:#363636; margin-bottom:6px;">
#             Noisy - clean
#           </figcaption>
#           <img
#             src="data:image/bmp;base64,..."
#             style="display:block; width:100%; image-rendering:auto; border:1px solid #000000;"
#           />
#         </figure>
#
#       </div>
#     </section>
#     <section style="font-family:system-ui, sans-serif;">
#       <h2 style="font-size:18px; margin:0 0 10px 0; color:#000000;">Rician Noise</h2>
#       <div style="display:grid; grid-template-columns:repeat(3, minmax(0, 1fr)); gap:12px;">
#
#         <figure style="margin:0; min-width:0;">
#           <figcaption style="font:600 13px system-ui; color:#363636; margin-bottom:6px;">
#             Clean 1024 image
#           </figcaption>
#           <img
#             src="data:image/bmp;base64,..."
#             style="display:block; width:100%; image-rendering:auto; border:1px solid #000000;"
#           />
#         </figure>
#
#
#         <figure style="margin:0; min-width:0;">
#           <figcaption style="font:600 13px system-ui; color:#363636; margin-bottom:6px;">
#             Noisy image
#           </figcaption>
#           <img
#             src="data:image/bmp;base64,..."
#             style="display:block; width:100%; image-rendering:auto; border:1px solid #000000;"
#           />
#         </figure>
#
#
#         <figure style="margin:0; min-width:0;">
#           <figcaption style="font:600 13px system-ui; color:#363636; margin-bottom:6px;">
#             Noisy - clean
#           </figcaption>
#           <img
#             src="data:image/bmp;base64,..."
#             style="display:block; width:100%; image-rendering:auto; border:1px solid #000000;"
#           />
#         </figure>
#
#       </div>
#     </section>

# %% [markdown]
# ## Timing
#
# Time one hot-path model application on the selected device.

# %%
if clean.is_cuda:
    torch.cuda.synchronize()
start = time.perf_counter()
_ = apply_model()
if clean.is_cuda:
    torch.cuda.synchronize()
elapsed_ms = (time.perf_counter() - start) * 1000.0
elapsed_ms
# Out:
# 35.441708052530885
