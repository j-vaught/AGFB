# %% [markdown]
# # Poisson Shot Noise 1024 synthetic-image example
#
# Photon-counting shot noise generated from nonnegative intensity. This notebook starts from the same synthetic 1024 x 1024 image, applies one AGFB noise model, and displays the clean image, noisy image, and residual.

# %% [markdown]
# ## Setup
#
# Import the model function and notebook helpers. The autoreload lines help Jupyter pick up local source edits without restarting the kernel.

# %%
# Imports and local reloads.
# %load_ext autoreload
# %autoreload 2

import time

import torch

from agfb_noise import add_poisson
from agfb_noise.notebook import show_noise_preview, summarize_tensors, synthetic_1024_image

# %% [markdown]
# ## Synthetic Image
#
# Create the shared 1024 x 1024 synthetic input on CUDA when available.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
seed = 123

clean = synthetic_1024_image(device=device)
clean.shape, clean.device, clean.dtype
# Out:
# (torch.Size([1, 1024, 1024]), device(type='cpu'), torch.float32)

# %% [markdown]
# ## Apply Noise
#
# Set the model parameters and corrupt the image.

# %%
def apply_model() -> torch.Tensor:
    return add_poisson(clean, peak=512.0, seed=seed, clamp=(0.0, 1.0))


noisy = apply_model()
delta = noisy - clean

# %% [markdown]
# ## Summary
#
# Report compact tensor statistics for the clean, noisy, and residual images.

# %%
summarize_tensors(
    {
        "clean": clean,
        "noisy": noisy,
        "delta": delta,
    }
)
# Out:
# [{'name': 'clean',
#   'min': 0.11334408074617386,
#   'q01': 0.1417168229818344,
#   'mean': 0.48850709199905396,
#   'q50': 0.5385441184043884,
#   'q99': 0.8480556011199951,
#   'max': 0.9545643329620361,
#   'std': 0.18355251848697662},
#  {'name': 'noisy',
#   'min': 0.0703125,
#   'q01': 0.134765625,
#   'mean': 0.4884227514266968,
#   'q50': 0.53515625,
#   'q99': 0.86328125,
#   'max': 1.0,
#   'std': 0.18606340885162354},
#  {'name': 'delta',
#   'min': -0.18324017524719238,
#   'q01': -0.07415476441383362,
#   'mean': -8.433742914348841e-05,
#   'q50': -0.0003761798143386841,
#   'q99': 0.07629214227199554,
#   'max': 0.1750759482383728,
#   'std': 0.030873598530888557}]

# %% [markdown]
# ## Preview
#
# The preview down-samples the 1024 image for display. The residual uses a blue-white-garnet diverging map.

# %%
show_noise_preview(clean, noisy, title="Poisson Shot Noise")
# Out:
#     <section style="font-family:system-ui, sans-serif;">
#       <h2 style="font-size:18px; margin:0 0 10px 0; color:#000000;">Poisson Shot Noise</h2>
#       <div style="display:grid; grid-template-columns:repeat(3, minmax(0, 1fr)); gap:12px;">
#
#         <figure style="margin:0; min-width:0;">
#           <figcaption style="font:600 13px system-ui; color:#363636; margin-bottom:6px;">
#             Clean 1024 image
#           </figcaption>
#           <img
#             src="data:image/bmp;base64,..."
#             style="display:block; width:100%; image-rendering:auto; border:1px solid #000000;"
#           />
#         </figure>
#
#
#         <figure style="margin:0; min-width:0;">
#           <figcaption style="font:600 13px system-ui; color:#363636; margin-bottom:6px;">
#             Noisy image
#           </figcaption>
#           <img
#             src="data:image/bmp;base64,..."
#             style="display:block; width:100%; image-rendering:auto; border:1px solid #000000;"
#           />
#         </figure>
#
#
#         <figure style="margin:0; min-width:0;">
#           <figcaption style="font:600 13px system-ui; color:#363636; margin-bottom:6px;">
#             Noisy - clean
#           </figcaption>
#           <img
#             src="data:image/bmp;base64,..."
#             style="display:block; width:100%; image-rendering:auto; border:1px solid #000000;"
#           />
#         </figure>
#
#       </div>
#     </section>
#     <section style="font-family:system-ui, sans-serif;">
#       <h2 style="font-size:18px; margin:0 0 10px 0; color:#000000;">Poisson Shot Noise</h2>
#       <div style="display:grid; grid-template-columns:repeat(3, minmax(0, 1fr)); gap:12px;">
#
#         <figure style="margin:0; min-width:0;">
#           <figcaption style="font:600 13px system-ui; color:#363636; margin-bottom:6px;">
#             Clean 1024 image
#           </figcaption>
#           <img
#             src="data:image/bmp;base64,..."
#             style="display:block; width:100%; image-rendering:auto; border:1px solid #000000;"
#           />
#         </figure>
#
#
#         <figure style="margin:0; min-width:0;">
#           <figcaption style="font:600 13px system-ui; color:#363636; margin-bottom:6px;">
#             Noisy image
#           </figcaption>
#           <img
#             src="data:image/bmp;base64,..."
#             style="display:block; width:100%; image-rendering:auto; border:1px solid #000000;"
#           />
#         </figure>
#
#
#         <figure style="margin:0; min-width:0;">
#           <figcaption style="font:600 13px system-ui; color:#363636; margin-bottom:6px;">
#             Noisy - clean
#           </figcaption>
#           <img
#             src="data:image/bmp;base64,..."
#             style="display:block; width:100%; image-rendering:auto; border:1px solid #000000;"
#           />
#         </figure>
#
#       </div>
#     </section>

# %% [markdown]
# ## Timing
#
# Time one hot-path model application on the selected device.

# %%
if clean.is_cuda:
    torch.cuda.synchronize()
start = time.perf_counter()
_ = apply_model()
if clean.is_cuda:
    torch.cuda.synchronize()
elapsed_ms = (time.perf_counter() - start) * 1000.0
elapsed_ms
# Out:
# 50.27354205958545
